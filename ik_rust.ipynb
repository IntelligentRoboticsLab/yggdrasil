// %%
:dep showata = { version = "0.3", features=["show_nalgebra"]}
:dep nalgebra = "^0.26"
:dep ndarray = "0.14"

use showata::Showable;
use nalgebra::{Isometry3, Translation3, Matrix};

// %%
let data = Isometry3::translation(0.0, 0.05, 0.0).to_matrix();
data.show()
// Out:
// [E0107] Error: missing generics for struct `Matrix`
//    ╭─[command_14:1:1]
//    │
//  2 │ let data: Matrix = Isometry3::translation(0.0, 0.05, 0.0).to_matrix();
//    │           ───┬──│
//    │              ╰──── expected 4 generic arguments
//    │                 │
//    │                 ╰─ help: add missing generic arguments: `<T, R, C, S>`
// ───╯
