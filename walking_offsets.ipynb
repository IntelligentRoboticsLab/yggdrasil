# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
# load data.csv
data = pd.read_csv("data.csv")
data.head()
# Out:
#        left     right
# 0  0.000118 -0.001215
# 1  0.000508 -0.002521
# 2  0.001099 -0.003707
# 3  0.001918 -0.004896
# 4  0.002958 -0.006081

# %%
# plot first 400 rows of the first column
plt.plot(data.iloc[0:222, 0], label="left")
plt.plot(data.iloc[0:222, 1], label="right")

plt.legend()
plt.show()
